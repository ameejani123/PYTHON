# %%
import pandas as pd
import numpy as np
import os

# %%
path=(r"C:\Users\hardjan\Instacart Basket Analysis March 2024")

# %%
df_ords_prods_merge_derived=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
df_ords_prods_merge_derived.drop(columns=['Unnamed:0_x','Unnamed:0.1','Unnamed:0_y','_merge'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_ords_prods_merge_derived.drop(columns=['Unnamed:0_x','Unnamed:0.1','Unnamed:0_y','_merge'], axis=1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
df_ords_prods_merge_derived = df_ords_prods_merge_derived.drop(columns = ['Unnamed:0_x','Unnamed:0.1','Unnamed:0_y','_merge'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_ords_prods_merge_derived = df_ords_prods_merge_derived.drop(columns = ['Unnamed:0_x','Unnamed:0.1','Unnamed:0_y','_merge'],axis=1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
# ...

# %%
df=df_ords_prods_merge_derived[:1000000]

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0             19     5.8         16802          1987   3139998      138  ...
# 1             19     5.8         16806          1989   1977647      138  ...
# ...

# %%
df.groupby('product_name')

# %%
list(df_ords_prods_merge_derived.columns.values)
# Out:
# ['Unnamed: 0_x',
#  'product_id',
#  'product_name',
#  'aisle_id',
#  'department_id',
#  'prices',
#  'Unnamed: 0.1',
#  'Unnamed: 0_y',
#  'order_id',
#  'user_id',
#  'order_sequence_number',
#  'orders_day_of_week',
#  'order_hour_of_day',
#  'days_since_prior_order',
#  'add_to_cart_order',
#  'reordered',
#  '_merge',
#  'price_range',
#  'price_range_loc',
#  'Busiest day',
#  'Busiest days',
#  'busiest_period_of_day']

# %%
df_ords_prods_merge_derived = df_ords_prods_merge_derived.drop(columns =['Unnamed: 0_x','Unnamed: 0.1','Unnamed: 0_y','_merge','price_range'],axis=1)

# %%
df_ords_prods_merge_derived.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_sequence_number  orders_day_of_week  \
# 0   3139998      138                     28                   6
# 1   1977647      138                     30                   6
# 2    389851      709                      2                   0
# 3    652770      764                      1                   3
# 4   1813452      764                      3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df.groupby('department_id')['order_sequence_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_sequence_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_sequence_number': ['mean']})
# Out:
#               order_sequence_number
#                                mean
# department_id
# 1                         15.577493
# 2                         17.320781
# 3                         16.084944
# 4                         17.530458
# 5                         14.763075
# 6                         16.658449
# 7                         17.031590
# 8                         15.076662
# 9                         15.447580
# 10                        18.681852
# 11                        15.447411
# 12                        14.327957
# 13                        16.548642
# 14                        16.960241
# 15                        16.121948
# 16                        17.803851
# 17                        15.593633
# 18                        19.674252
# 19                        16.899756
# 20                        16.255442
# 21                        25.535479

# %%
df.groupby('department_id').agg({'order_sequence_number': ['mean', 'min', 'max']})
# Out:
#               order_sequence_number
#                                mean min max
# department_id
# 1                         15.577493   1  99
# 2                         17.320781   1  96
# 3                         16.084944   1  99
# 4                         17.530458   1  99
# 5                         14.763075   1  99
# 6                         16.658449   1  99
# 7                         17.031590   1  99
# 8                         15.076662   1  98
# 9                         15.447580   1  99
# 10                        18.681852   1  99
# 11                        15.447411   1  99
# 12                        14.327957   1  99
# 13                        16.548642   1  99
# 14                        16.960241   1  99
# 15                        16.121948   1  99
# 16                        17.803851   1  99
# 17                        15.593633   1  99
# 18                        19.674252   1  99
# 19                        16.899756   1  99
# ...

# %%
df_ords_prods_merge_derived['max_order']=df_ords_prods_merge_derived.groupby(['user_id'])['order_sequence_number'].transform(np.max)
# Out:
# C:\Users\hardjan\AppData\Local\Temp\ipykernel_10504\3517166906.py:1: FutureWarning: The provided callable <function max at 0x00000229B007B4C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge_derived['max_order']=df_ords_prods_merge_derived.groupby(['user_id'])['order_sequence_number'].transform(np.max)

# %%
df_ords_prods_merge_derived.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# ...

# %%
df_ords_prods_merge_derived.head(100)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# ..           ...         ...                         ...       ...
# 95             0           1  Chocolate Sandwich Cookies        61
# 96             0           1  Chocolate Sandwich Cookies        61
# 97             0           1  Chocolate Sandwich Cookies        61
# 98             0           1  Chocolate Sandwich Cookies        61
# 99             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8         16802          1987   3139998      138  ...
# ...

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge_derived.loc[df_ords_prods_merge_derived['max_order']>40,'Loyalty_flag']='Loyal Customer'

# %%
df_ords_prods_merge_derived.loc[(df_ords_prods_merge_derived['max_order']<=40 )& (df_ords_prods_merge_derived['max_order']>10),'Loyalty_flag']='Regular Customer'

# %%
df_ords_prods_merge_derived.loc[df_ords_prods_merge_derived['max_order']<=10,'Loyalty_flag']='New Customer'

# %%
df_ords_prods_merge_derived['Loyalty_flag'].value_counts(dropna=False)
# Out:
# Loyalty_flag
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merge_derived[['user_id', 'Loyalty_flag', 'order_sequence_number']].head(60)
# Out:
#     user_id      Loyalty_flag  order_sequence_number
# 0       138  Regular Customer                     28
# 1       138  Regular Customer                     30
# 2       709      New Customer                      2
# 3       764      New Customer                      1
# 4       764      New Customer                      3
# 5       777  Regular Customer                     16
# 6       825      New Customer                      3
# 7       910  Regular Customer                     12
# 8      1052  Regular Customer                     10
# 9      1052  Regular Customer                     15
# 10     1379      New Customer                      1
# 11     1480    Loyal Customer                     36
# 12     1480    Loyal Customer                     38
# 13     1480    Loyal Customer                     39
# 14     1494  Regular Customer                      6
# 15     1494  Regular Customer                      7
# 16     1494  Regular Customer                      9
# ...

# %% [markdown]
# ## Export Data Frame as Pickle to prepared data folder

# %%
df_ords_prods_merge_derived.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived(4.8).pkl'))
