# %%
#01 Importing Libraries
# Out:
#   Cell In[60], line 1
#     01 Importing Libraries
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
#import libraries
import numpy as np
import pandas as pd
import os

# %%
Instacart Basket Analysis March 2024 \02 Data\Original Dataorders.csv

# %%
df=pd.read_csv(r"C:\Users\hardjan\Instacart Basket Analysis March 2024\02 Data\Original Data\orders.csv", index_col = False)

# %%
df=pd.read_csv(r"C:\Users\hardjan\Instacart Basket Analysis March 2024\02 Data\Original Data\products.csv", index_col = False)

# %%
path=(r"C:\Users\hardjan\Instacart Basket Analysis March 2024")

# %%
path

# %%
#importing orders data set 
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(30)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# 13   1901567        2             3          1                 10
# 14    738281        2             4          2                 10
# 15   1673511        2             5          3                 11
# 16   1199898        2             6          2                  9
# 17   3194192        2             7          2                 12
# 18    788338        2             8          1                 15
# 19   1718559        2             9          2                  9
# 20   1447487        2            10          1                 11
# 21   1402090        2            11          1                 10
# 22   3186735        2            12          1                  9
# 23   3268552        2            13          4                 11
# 24    839880        2            14          3                 10
# 25   1492625        2            15          1                 11
# 26   1374495        3             1          1                 14
# 27    444309        3             2          3                 19
# 28   3002854        3             3          3                 16
# 29   2037211        3             4          2                 18
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# 6                     20.0
# 7                     14.0
# 8                      0.0
# 9                     30.0
# 10                    14.0
# 11                     NaN
# 12                    10.0
# 13                     3.0
# 14                     8.0
# 15                     8.0
# 16                    13.0
# 17                    14.0
# 18                    27.0
# 19                     8.0
# 20                     6.0
# 21                    30.0
# 22                    28.0
# 23                    30.0
# 24                    13.0
# 25                    30.0
# 26                     NaN
# 27                     9.0
# 28                    21.0
# 29                    20.0

# %%
df.tail()
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 3421078                    29.0
# 3421079                    30.0
# 3421080                    18.0
# 3421081                     7.0
# 3421082                    30.0

# %%
df.tail(10)
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421073   2307371   206209             5          4                 15
# 3421074   3186442   206209             6          0                 16
# 3421075    550836   206209             7          2                 13
# 3421076   2129269   206209             8          3                 17
# 3421077   2558525   206209             9          4                 15
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 3421073                     3.0
# 3421074                     3.0
# 3421075                     9.0
# 3421076                    22.0
# 3421077                    22.0
# 3421078                    29.0
# 3421079                    30.0
# 3421080                    18.0
# 3421081                     7.0
# 3421082                    30.0

# %%
df.shape
# Out:
# (3421083, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   order_dow               int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(5)
# memory usage: 156.6 MB

# %%
df.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# max         2.300000e+01            3.000000e+01

# %%
df=pd.read_csv(os.path.join(path,'02 Data','Original data','orders.csv'),nrows=1000)

# %%
vars_list=['order_id','user_id','order_number','order_dow','order_hour_of_day','days_since_prior_order']

# %%
df=pd.read_csv(os.path.join(path,'02 Data','Original Data','orders.csv'), usecols = vars_list)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
